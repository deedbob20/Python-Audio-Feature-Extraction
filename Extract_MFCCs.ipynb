# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np

# %%
pluck1, sr = librosa.load('/Users/adamdeedman/Documents/University/Lectures/Third Year/FYP/Python Stage/IDMT-SMT-BASS/PS/FS/BS_1_EQ_1_FS_NO_1_10.wav')

# load sound file (and sample rate)

# %%
ipd.Audio(data=pluck1, rate=sr)

# play sound file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mfccs = librosa.feature.mfcc(pluck1, n_mfcc=13, sr=sr)

# extract 13 MFCC values from signal
# Out:
# /var/folders/sl/ymrr09g50yv065qjdfh1d8h80000gn/T/ipykernel_27021/3868401728.py:1: FutureWarning: Pass y=[-1.1093048e-03 -1.5385096e-03 -1.1799845e-03 ...  1.1227579e-04
#   4.9619593e-05 -7.4583863e-07] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfccs = librosa.feature.mfcc(pluck1, n_mfcc=13, sr=sr)

# %%
plt.figure(figsize=(25,10))
librosa.display.specshow(mfccs, x_axis="time", sr=sr)
plt.colorbar(format="%+2f")
plt.show()

# visualisation of MFCCs

# %%
delta_mfccs = librosa.feature.delta(mfccs)
delta2_mfccs = librosa.feature.delta(mfccs, order=2)

# extract delta and delta2 mfccs

# %%
plt.figure(figsize=(25,10))
librosa.display.specshow(delta_mfccs, x_axis="time", sr=sr)
plt.colorbar(format="%+2f")
plt.show()

# visualise delta mfccs

# %%
plt.figure(figsize=(25,10))
librosa.display.specshow(delta2_mfccs, x_axis="time", sr=sr)
plt.colorbar(format="%+2f")
plt.show()

# visualise delta2 mfccs

# %%
comprehensive_mfccs = np.concatenate((mfccs, delta_mfccs, delta2_mfccs))
